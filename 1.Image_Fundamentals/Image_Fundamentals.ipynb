# %%
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pwd
# Out:
# /content/drive/My Drive/Data_Science_Project/1.Andrian_Roseborck_DL_for_CV/1.Image_Fundamentals

# %%
% cd './drive/My Drive/Data_Science_Project/1.Andrian_Roseborck_DL_for_CV/1.Image_Fundamentals'

# %%
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
#Load and image from disk Using OpenCV
#pip install opencv-python

image = cv2.imread("./example.jpg")
print(image.shape)
plt.imshow(image)
plt.show()
# Out:
# (2525, 4000, 3)

# %%
#OpenCV stores channels in reverse order Blue-Green-red
(b, g, r) = image[20,100] # accesses pixel at x=100, y=20
print(b, g, r)
# Out:
# 241 235 228

# %%
#Fibonacci Function 
def fib(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
fib(7)
# Out:
# 13
